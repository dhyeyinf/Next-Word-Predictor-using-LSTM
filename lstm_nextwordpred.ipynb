# %%
text="""We can notice the occurrence of graphs everywhere.
When faced with decision making one of the first approaches that are thaught to children are decision trees.
Later on, we are prompted to draw mind maps. With a little bit of observation, we can see that social circles are also graphs.
Roads and cities can be graphs, molecules can be graphs and even citing papers in this article can form a graph.
So what is a graph exactly?
We can imagine it as a set of nodes that are connected with edges.
Both of these can carry information, for example, gas consumption or time needed to travel from one city to another.
Networks can have many different qualities, they can be directed or undirected, connected or unconnected, bipartite, etc.
Graph traits can be represented by node, edge, and graph features.
Graph theory started developing way before we ever knew about computers or let alone cryptocurrency.
While there are still many unanswered theoretical questions in this field alone, scientists then started using computers to solve certain graph problems such as searching for the shortest path or perhaps the lowest cost between two nodes.
What comes next? In the modern day and age, we became baffled by the results artificial intelligence can bring.
Art crafted at the hands of a computer, whole conversations with our refrigerators, face recognition to unlock our phones and so much more! Image recognition uses matrices as input and speech recognition manipulates sequences.
Experts in this field of research asked a wonderful question — what would happen if we trained our models on graphs? While it did take some adjusting and changes, we now have many different ML models for such tasks and we used one of them to show just how useful they can be.
A Bitcoin transaction is the transfer of value from one Bitcoin address to another.
While understanding the mechanisms in detail is not crucial, it does explain why tackle this problem in the first place.
First, the transaction is initiated when the sender creates a new transaction of funds.
This includes specifying the recipient, the amount of money sent, and other information.
It generates a unique private key that is later used for verification.
The transaction is then broadcasted to the Bitcoin network and this is where graphs come into the equation.
Verification by miners on the network who solve complex mathematical problems is required for the funds to go through.
Now the transaction is finally added to the blockchain and it is considered confirmed.
When a transaction is broadcasted, it is picked up and forwarded by multiple nodes.
A few years back an interesting article was published by Mark Weber called Experimenting with Graph Convolutional Networks for Financial Forensics.
It provides an Eliptic Data Set of Bitcoin Transaction Graph. The nodes represent transactions and edges the flow of Bitcoins between them.
This graph is not connected but can be viewed as a set of connected directed graphs each in a different timeframe.
Each step captures 3 hours of continuous network traffic. The steps are evenly spaced with 2 weeks between graphs.
Altogether there are 49 timeframes, 203,769 nodes, and 234,355 edges.
There are 3 different labels for the nodes.
The transaction can be labeled as licit, illicit, or unknown.
Each node also has 166 features. Let’s choose one transaction and look at its features.
The first 94 are local information that is obtained at the initialization.
For every graph, each node has its own neighborhood of nodes that are one hop away.
The quantity of these nodes is described as a node degree.
If we want to represent the graph even better it is good to learn the neighborhood properties as well, so the remaining features are aggregated features of these neighbors.
An example of aggregation would be the maximum, minimum, standard deviation, and correlation coef
ficients of neighboring local information.
Do all neighbors hold the same weight?
Are illicit nodes perhaps more important than licit ones? We ended up with 2 different strategies.
First, we will treat all the neighboring nodes as equal using a Graph Convolutional Network model, or GCN for short.
We decided to compare the result with the one of a Graph Attention Network (GAT) model and see which one performs better.
This last one presumes not all nodes are of the same importance by giving them different weights.
But how should we measure our classification performance?
There are many measures and we opted for the F1 score.
Considering our particular situation the worst possible prediction is a false negative one.
Predicting a node to be licit and it is actually illicit is way worse than the other way around, so this score works best in this scenario.
Each node of the graph is represented as a feature vector.
Every single one of these is then updated by aggregating information from its neighboring nodes.
The process is named graph convolution and is largely based on the convolution in traditional convolutional neural networks (CNNs).
This model is just one of many in the graph neural network (GNN) family.
They all generate embeddings that are later used for downstream tasks.
If two embeddings are close in their embedding space the nodes in the observed graph are similar.
The reason why we need these and not just use classic CNNs is that graphs in reality have no order.
The structure of a graph is permutable and the output of the model cannot depend on its physical structure.
Now to overcome this problem let’s look at the basic GNN structure. Each node gets its own computational graph.
We calculate the embeddings in 3 crucial steps. First, each neighboring node sends a message.
The messages are then aggregated and finally, the embedding of our node is updated.
The only difference when using GAT is that we do not take the average but instead we add attention weights to each message.
These are also learned.
This way we can put more attention to the important bits of the data we used for training.
In the picture above we can see that K layers are used, K being the last one.
This means we acquire data from K-hops away and only the nodes whose paths are of this length or less can influence our final embedding.
The segments of code that are being shown here are only the important parts that we thought could use some explaining.
The whole program is available on GitHub. It is based on the PyTorch Geometric module that is built on top of PyTorch.
It provides a set of tools for deep learning on graphs.
Firstly, let’s view how to interpret the data.
It comes in 3 files: one documents the 3 possible classes, the second has all of the features and the last one gives us an edge index.
We then used NetworkX implementation for our graphs.
Index 0 represents the illicit label, 1 is the licit label and 2 is for all of the unlabeled nodes.
There are some interesting statistics to be seen in our Colab, so we recommend you check it out!
We used 39 of the graphs for the training set on which we trained the model and the other 10 for the testing set
Then we implemented our models.
We use PyTorch Geometric’s implementation for the convolution layers.
This works for both GCN and GAT because we have a separate configuration part where we define the parameters and decide which convolution model to use.
We optimized the training by doing repeated k-fold cross-validation.
Instead of just having trained the model and validating the model once, we split out the training set into k equally sized parts.
Then the model is trained on the k-1 parts and later on validated on the remaining 1.
This process is repeated k times, with each part or so-called fold used once as the validation set.
This approach helps to reduce the impact of the randomness in the train-validation split on the performance and makes the model more reliable.
This is the algorithm.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts([text])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'of': 2,
#  'is': 3,
#  'we': 4,
#  'and': 5,
#  'are': 6,
#  'a': 7,
#  'to': 8,
#  'this': 9,
#  'graph': 10,
#  'for': 11,
#  'in': 12,
#  'can': 13,
#  'one': 14,
#  'nodes': 15,
#  'on': 16,
#  'that': 17,
#  'it': 18,
#  'graphs': 19,
#  'be': 20,
#  'as': 21,
#  'our': 22,
#  'model': 23,
#  'with': 24,
#  'or': 25,
#  'node': 26,
#  'transaction': 27,
#  'each': 28,
#  'set': 29,
#  'by': 30,
#  'used': 31,
#  'then': 32,
#  'k': 33,
#  'first': 34,
#  'so': 35,
#  'these': 36,
#  'different': 37,
#  'features': 38,
#  'network': 39,
#  'all': 40,
#  'information': 41,
#  'many': 42,
#  'there': 43,
#  'not': 44,
#  '3': 45,
#  'its': 46,
#  'when': 47,
#  'later': 48,
#  'connected': 49,
#  'from': 50,
#  'have': 51,
#  'way': 52,
#  'at': 53,
#  'more': 54,
#  'trained': 55,
#  'just': 56,
#  'bitcoin': 57,
#  'an': 58,
#  'data': 59,
#  'licit': 60,
#  'illicit': 61,
#  'neighboring': 62,
#  'convolution': 63,
#  'use': 64,
#  'training': 65,
#  'see': 66,
#  'also': 67,
#  'what': 68,
#  'edges': 69,
#  'networks': 70,
#  'they': 71,
#  'while': 72,
#  'using': 73,
#  'between': 74,
#  'recognition': 75,
#  'if': 76,
#  'models': 77,
#  'some': 78,
#  'now': 79,
#  'them': 80,
#  'how': 81,
#  'other': 82,
#  'convolutional': 83,
#  'but': 84,
#  '2': 85,
#  'has': 86,
#  'let’s': 87,
#  'important': 88,
#  'attention': 89,
#  'gat': 90,
#  'which': 91,
#  'last': 92,
#  'embeddings': 93,
#  'embedding': 94,
#  'structure': 95,
#  'only': 96,
#  'parts': 97,
#  'pytorch': 98,
#  '1': 99,
#  'validation': 100,
#  'decision': 101,
#  'even': 102,
#  'article': 103,
#  'both': 104,
#  'example': 105,
#  'another': 106,
#  'directed': 107,
#  'represented': 108,
#  'edge': 109,
#  'started': 110,
#  'computers': 111,
#  'alone': 112,
#  'field': 113,
#  'solve': 114,
#  'problems': 115,
#  'such': 116,
#  'perhaps': 117,
#  'two': 118,
#  'comes': 119,
#  'whole': 120,
#  'would': 121,
#  'take': 122,
#  'tasks': 123,
#  'crucial': 124,
#  'why': 125,
#  'problem': 126,
#  'funds': 127,
#  'verification': 128,
#  'broadcasted': 129,
#  'where': 130,
#  'into': 131,
#  'finally': 132,
#  'up': 133,
#  'interesting': 134,
#  'called': 135,
#  'provides': 136,
#  'represent': 137,
#  'steps': 138,
#  'look': 139,
#  'local': 140,
#  'every': 141,
#  'own': 142,
#  'neighborhood': 143,
#  'away': 144,
#  'better': 145,
#  'remaining': 146,
#  'aggregated': 147,
#  'neighbors': 148,
#  'do': 149,
#  'same': 150,
#  'than': 151,
#  'gcn': 152,
#  'weights': 153,
#  'performance': 154,
#  'score': 155,
#  'possible': 156,
#  'works': 157,
#  'updated': 158,
#  'process': 159,
#  'based': 160,
#  'neural': 161,
#  'cnns': 162,
#  'gnn': 163,
#  'message': 164,
#  'instead': 165,
#  'layers': 166,
#  'being': 167,
#  'index': 168,
#  'implementation': 169,
#  'label': 170,
#  'out': 171,
#  'part': 172,
#  'repeated': 173,
#  'fold': 174,
#  'once': 175,
#  'split': 176,
#  'notice': 177,
#  'occurrence': 178,
#  'everywhere': 179,
#  'faced': 180,
#  'making': 181,
#  'approaches': 182,
#  'thaught': 183,
#  'children': 184,
#  'trees': 185,
#  'prompted': 186,
#  'draw': 187,
#  'mind': 188,
#  'maps': 189,
#  'little': 190,
#  'bit': 191,
#  'observation': 192,
#  'social': 193,
#  'circles': 194,
#  'roads': 195,
#  'cities': 196,
#  'molecules': 197,
#  'citing': 198,
#  'papers': 199,
#  'form': 200,
#  'exactly': 201,
#  'imagine': 202,
#  'carry': 203,
#  'gas': 204,
#  'consumption': 205,
#  'time': 206,
#  'needed': 207,
#  'travel': 208,
#  'city': 209,
#  'qualities': 210,
#  'undirected': 211,
#  'unconnected': 212,
#  'bipartite': 213,
#  'etc': 214,
#  'traits': 215,
#  'theory': 216,
#  'developing': 217,
#  'before': 218,
#  'ever': 219,
#  'knew': 220,
#  'about': 221,
#  'let': 222,
#  'cryptocurrency': 223,
#  'still': 224,
#  'unanswered': 225,
#  'theoretical': 226,
#  'questions': 227,
#  'scientists': 228,
#  'certain': 229,
#  'searching': 230,
#  'shortest': 231,
#  'path': 232,
#  'lowest': 233,
#  'cost': 234,
#  'next': 235,
#  'modern': 236,
#  'day': 237,
#  'age': 238,
#  'became': 239,
#  'baffled': 240,
#  'results': 241,
#  'artificial': 242,
#  'intelligence': 243,
#  'bring': 244,
#  'art': 245,
#  'crafted': 246,
#  'hands': 247,
#  'computer': 248,
#  'conversations': 249,
#  'refrigerators': 250,
#  'face': 251,
#  'unlock': 252,
#  'phones': 253,
#  'much': 254,
#  'image': 255,
#  'uses': 256,
#  'matrices': 257,
#  'input': 258,
#  'speech': 259,
#  'manipulates': 260,
#  'sequences': 261,
#  'experts': 262,
#  'research': 263,
#  'asked': 264,
#  'wonderful': 265,
#  'question': 266,
#  '—': 267,
#  'happen': 268,
#  'did': 269,
#  'adjusting': 270,
#  'changes': 271,
#  'ml': 272,
#  'show': 273,
#  'useful': 274,
#  'transfer': 275,
#  'value': 276,
#  'address': 277,
#  'understanding': 278,
#  'mechanisms': 279,
#  'detail': 280,
#  'does': 281,
#  'explain': 282,
#  'tackle': 283,
#  'place': 284,
#  'initiated': 285,
#  'sender': 286,
#  'creates': 287,
#  'new': 288,
#  'includes': 289,
#  'specifying': 290,
#  'recipient': 291,
#  'amount': 292,
#  'money': 293,
#  'sent': 294,
#  'generates': 295,
#  'unique': 296,
#  'private': 297,
#  'key': 298,
#  'come': 299,
#  'equation': 300,
#  'miners': 301,
#  'who': 302,
#  'complex': 303,
#  'mathematical': 304,
#  'required': 305,
#  'go': 306,
#  'through': 307,
#  'added': 308,
#  'blockchain': 309,
#  'considered': 310,
#  'confirmed': 311,
#  'picked': 312,
#  'forwarded': 313,
#  'multiple': 314,
#  'few': 315,
#  'years': 316,
#  'back': 317,
#  'was': 318,
#  'published': 319,
#  'mark': 320,
#  'weber': 321,
#  'experimenting': 322,
#  'financial': 323,
#  'forensics': 324,
#  'eliptic': 325,
#  'transactions': 326,
#  'flow': 327,
#  'bitcoins': 328,
#  'viewed': 329,
#  'timeframe': 330,
#  'step': 331,
#  'captures': 332,
#  'hours': 333,
#  'continuous': 334,
#  'traffic': 335,
#  'evenly': 336,
#  'spaced': 337,
#  'weeks': 338,
#  'altogether': 339,
#  '49': 340,
#  'timeframes': 341,
#  '203': 342,
#  '769': 343,
#  '234': 344,
#  '355': 345,
#  'labels': 346,
#  'labeled': 347,
#  'unknown': 348,
#  '166': 349,
#  'choose': 350,
#  '94': 351,
#  'obtained': 352,
#  'initialization': 353,
#  'hop': 354,
#  'quantity': 355,
#  'described': 356,
#  'degree': 357,
#  'want': 358,
#  'good': 359,
#  'learn': 360,
#  'properties': 361,
#  'well': 362,
#  'aggregation': 363,
#  'maximum': 364,
#  'minimum': 365,
#  'standard': 366,
#  'deviation': 367,
#  'correlation': 368,
#  'coef': 369,
#  'ficients': 370,
#  'hold': 371,
#  'weight': 372,
#  'ones': 373,
#  'ended': 374,
#  'strategies': 375,
#  'will': 376,
#  'treat': 377,
#  'equal': 378,
#  'short': 379,
#  'decided': 380,
#  'compare': 381,
#  'result': 382,
#  'performs': 383,
#  'presumes': 384,
#  'importance': 385,
#  'giving': 386,
#  'should': 387,
#  'measure': 388,
#  'classification': 389,
#  'measures': 390,
#  'opted': 391,
#  'f1': 392,
#  'considering': 393,
#  'particular': 394,
#  'situation': 395,
#  'worst': 396,
#  'prediction': 397,
#  'false': 398,
#  'negative': 399,
#  'predicting': 400,
#  'actually': 401,
#  'worse': 402,
#  'around': 403,
#  'best': 404,
#  'scenario': 405,
#  'feature': 406,
#  'vector': 407,
#  'single': 408,
#  'aggregating': 409,
#  'named': 410,
#  'largely': 411,
#  'traditional': 412,
#  'family': 413,
#  'generate': 414,
#  'downstream': 415,
#  'close': 416,
#  'their': 417,
#  'space': 418,
#  'observed': 419,
#  'similar': 420,
#  'reason': 421,
#  'need': 422,
#  'classic': 423,
#  'reality': 424,
#  'no': 425,
#  'order': 426,
#  'permutable': 427,
#  'output': 428,
#  'cannot': 429,
#  'depend': 430,
#  'physical': 431,
#  'overcome': 432,
#  'basic': 433,
#  'gets': 434,
#  'computational': 435,
#  'calculate': 436,
#  'sends': 437,
#  'messages': 438,
#  'difference': 439,
#  'average': 440,
#  'add': 441,
#  'learned': 442,
#  'put': 443,
#  'bits': 444,
#  'picture': 445,
#  'above': 446,
#  'means': 447,
#  'acquire': 448,
#  'hops': 449,
#  'whose': 450,
#  'paths': 451,
#  'length': 452,
#  'less': 453,
#  'influence': 454,
#  'final': 455,
#  'segments': 456,
#  'code': 457,
#  'shown': 458,
#  'here': 459,
#  'thought': 460,
#  'could': 461,
#  'explaining': 462,
#  'program': 463,
#  'available': 464,
#  'github': 465,
#  'geometric': 466,
#  'module': 467,
#  'built': 468,
#  'top': 469,
#  'tools': 470,
#  'deep': 471,
#  'learning': 472,
#  'firstly': 473,
#  'view': 474,
#  'interpret': 475,
#  'files': 476,
#  'documents': 477,
#  'classes': 478,
#  'second': 479,
#  'gives': 480,
#  'us': 481,
#  'networkx': 482,
#  '0': 483,
#  'represents': 484,
#  'unlabeled': 485,
#  'statistics': 486,
#  'seen': 487,
#  'colab': 488,
#  'recommend': 489,
#  'you': 490,
#  'check': 491,
#  '39': 492,
#  '10': 493,
#  'testing': 494,
#  'implemented': 495,
#  'geometric’s': 496,
#  'because': 497,
#  'separate': 498,
#  'configuration': 499,
#  'define': 500,
#  'parameters': 501,
#  'decide': 502,
#  'optimized': 503,
#  'doing': 504,
#  'cross': 505,
#  'having': 506,
#  'validating': 507,
#  'equally': 508,
#  'sized': 509,
#  'validated': 510,
#  'times': 511,
#  'approach': 512,
#  'helps': 513,
#  'reduce': 514,
#  'impact': 515,
#  'randomness': 516,
#  'train': 517,
#  'makes': 518,
#  'reliable': 519,
#  'algorithm': 520}

# %%
input_seq=[]
for sentence in text.split('\n'):
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_seq.append(tokenized_sentence[:i+1])

# %%
input_seq
# Out:
# [[4, 13],
#  [4, 13, 177],
#  [4, 13, 177, 1],
#  [4, 13, 177, 1, 178],
#  [4, 13, 177, 1, 178, 2],
#  [4, 13, 177, 1, 178, 2, 19],
#  [4, 13, 177, 1, 178, 2, 19, 179],
#  [47, 180],
#  [47, 180, 24],
#  [47, 180, 24, 101],
#  [47, 180, 24, 101, 181],
#  [47, 180, 24, 101, 181, 14],
#  [47, 180, 24, 101, 181, 14, 2],
#  [47, 180, 24, 101, 181, 14, 2, 1],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6, 183],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6, 183, 8],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6, 183, 8, 184],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6, 183, 8, 184, 6],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6, 183, 8, 184, 6, 101],
#  [47, 180, 24, 101, 181, 14, 2, 1, 34, 182, 17, 6, 183, 8, 184, 6, 101, 185],
#  [48, 16],
#  [48, 16, 4],
#  [48, 16, 4, 6],
#  [48, 16, 4, 6, 186],
#  [48, 16, 4, 6, 186, 8],
#  [48, 16, 4, 6, 186, 8, 187],
#  [48, 16, 4, 6, 186, 8, 187, 188],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191, 2],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191, 2, 192],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191, 2, 192, 4],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191, 2, 192, 4, 13],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191, 2, 192, 4, 13, 66],
#  [48, 16, 4, 6, 186, 8, 187, 188, 189, 24, 7, 190, 191, 2, 192, 4, 13, 66, 17],
#  [48,
#   16,
#   4,
#   6,
#   186,
#   8,
#   187,
#   188,
#   189,
#   24,
#   7,
#   190,
#   191,
#   2,
#   192,
#   4,
#   13,
#   66,
#   17,
#   193],
#  [48,
#   16,
#   4,
#   6,
#   186,
#   8,
#   187,
#   188,
#   189,
#   24,
#   7,
#   190,
#   191,
#   2,
#   192,
#   4,
#   13,
#   66,
#   17,
#   193,
#   194],
#  [48,
#   16,
#   4,
#   6,
#   186,
#   8,
#   187,
#   188,
#   189,
#   24,
#   7,
#   190,
#   191,
#   2,
#   192,
#   4,
#   13,
#   66,
#   17,
#   193,
#   194,
#   6],
#  [48,
#   16,
#   4,
#   6,
#   186,
#   8,
#   187,
#   188,
#   189,
#   24,
#   7,
#   190,
#   191,
#   2,
#   192,
#   4,
#   13,
#   66,
#   17,
#   193,
#   194,
#   6,
#   67],
#  [48,
#   16,
#   4,
#   6,
#   186,
#   8,
#   187,
#   188,
#   189,
#   24,
#   7,
#   190,
#   191,
#   2,
#   192,
#   4,
#   13,
#   66,
#   17,
#   193,
#   194,
#   6,
#   67,
#   19],
#  [195, 5],
#  [195, 5, 196],
#  [195, 5, 196, 13],
#  [195, 5, 196, 13, 20],
#  [195, 5, 196, 13, 20, 19],
#  [195, 5, 196, 13, 20, 19, 197],
#  [195, 5, 196, 13, 20, 19, 197, 13],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102, 198],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102, 198, 199],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102, 198, 199, 12],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102, 198, 199, 12, 9],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102, 198, 199, 12, 9, 103],
#  [195, 5, 196, 13, 20, 19, 197, 13, 20, 19, 5, 102, 198, 199, 12, 9, 103, 13],
#  [195,
#   5,
#   196,
#   13,
#   20,
#   19,
#   197,
#   13,
#   20,
#   19,
#   5,
#   102,
#   198,
#   199,
#   12,
#   9,
#   103,
#   13,
#   200],
#  [195,
#   5,
#   196,
#   13,
#   20,
#   19,
#   197,
#   13,
#   20,
#   19,
#   5,
#   102,
#   198,
#   199,
#   12,
#   9,
#   103,
#   13,
#   200,
#   7],
#  [195,
#   5,
#   196,
#   13,
#   20,
#   19,
#   197,
#   13,
#   20,
#   19,
#   5,
#   102,
#   198,
#   199,
#   12,
#   9,
#   103,
#   13,
#   200,
#   7,
#   10],
#  [35, 68],
#  [35, 68, 3],
#  [35, 68, 3, 7],
#  [35, 68, 3, 7, 10],
#  [35, 68, 3, 7, 10, 201],
#  [4, 13],
#  [4, 13, 202],
#  [4, 13, 202, 18],
#  [4, 13, 202, 18, 21],
#  [4, 13, 202, 18, 21, 7],
#  [4, 13, 202, 18, 21, 7, 29],
#  [4, 13, 202, 18, 21, 7, 29, 2],
#  [4, 13, 202, 18, 21, 7, 29, 2, 15],
#  [4, 13, 202, 18, 21, 7, 29, 2, 15, 17],
#  [4, 13, 202, 18, 21, 7, 29, 2, 15, 17, 6],
#  [4, 13, 202, 18, 21, 7, 29, 2, 15, 17, 6, 49],
#  [4, 13, 202, 18, 21, 7, 29, 2, 15, 17, 6, 49, 24],
#  [4, 13, 202, 18, 21, 7, 29, 2, 15, 17, 6, 49, 24, 69],
#  [104, 2],
#  [104, 2, 36],
#  [104, 2, 36, 13],
#  [104, 2, 36, 13, 203],
#  [104, 2, 36, 13, 203, 41],
#  [104, 2, 36, 13, 203, 41, 11],
#  [104, 2, 36, 13, 203, 41, 11, 105],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25, 206],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25, 206, 207],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25, 206, 207, 8],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25, 206, 207, 8, 208],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25, 206, 207, 8, 208, 50],
#  [104, 2, 36, 13, 203, 41, 11, 105, 204, 205, 25, 206, 207, 8, 208, 50, 14],
#  [104,
#   2,
#   36,
#   13,
#   203,
#   41,
#   11,
#   105,
#   204,
#   205,
#   25,
#   206,
#   207,
#   8,
#   208,
#   50,
#   14,
#   209],
#  [104,
#   2,
#   36,
#   13,
#   203,
#   41,
#   11,
#   105,
#   204,
#   205,
#   25,
#   206,
#   207,
#   8,
#   208,
#   50,
#   14,
#   209,
#   8],
#  [104,
#   2,
#   36,
#   13,
#   203,
#   41,
#   11,
#   105,
#   204,
#   205,
#   25,
#   206,
#   207,
#   8,
#   208,
#   50,
#   14,
#   209,
#   8,
#   106],
#  [70, 13],
#  [70, 13, 51],
#  [70, 13, 51, 42],
#  [70, 13, 51, 42, 37],
#  [70, 13, 51, 42, 37, 210],
#  [70, 13, 51, 42, 37, 210, 71],
#  [70, 13, 51, 42, 37, 210, 71, 13],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25, 211],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25, 211, 49],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25, 211, 49, 25],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25, 211, 49, 25, 212],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25, 211, 49, 25, 212, 213],
#  [70, 13, 51, 42, 37, 210, 71, 13, 20, 107, 25, 211, 49, 25, 212, 213, 214],
#  [10, 215],
#  [10, 215, 13],
#  [10, 215, 13, 20],
#  [10, 215, 13, 20, 108],
#  [10, 215, 13, 20, 108, 30],
#  [10, 215, 13, 20, 108, 30, 26],
#  [10, 215, 13, 20, 108, 30, 26, 109],
#  [10, 215, 13, 20, 108, 30, 26, 109, 5],
#  [10, 215, 13, 20, 108, 30, 26, 109, 5, 10],
#  [10, 215, 13, 20, 108, 30, 26, 109, 5, 10, 38],
#  [10, 216],
#  [10, 216, 110],
#  [10, 216, 110, 217],
#  [10, 216, 110, 217, 52],
#  [10, 216, 110, 217, 52, 218],
#  [10, 216, 110, 217, 52, 218, 4],
#  [10, 216, 110, 217, 52, 218, 4, 219],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220, 221],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220, 221, 111],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220, 221, 111, 25],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220, 221, 111, 25, 222],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220, 221, 111, 25, 222, 112],
#  [10, 216, 110, 217, 52, 218, 4, 219, 220, 221, 111, 25, 222, 112, 223],
#  [72, 43],
#  [72, 43, 6],
#  [72, 43, 6, 224],
#  [72, 43, 6, 224, 42],
#  [72, 43, 6, 224, 42, 225],
#  [72, 43, 6, 224, 42, 225, 226],
#  [72, 43, 6, 224, 42, 225, 226, 227],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113, 112],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113, 112, 228],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113, 112, 228, 32],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113, 112, 228, 32, 110],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113, 112, 228, 32, 110, 73],
#  [72, 43, 6, 224, 42, 225, 226, 227, 12, 9, 113, 112, 228, 32, 110, 73, 111],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117,
#   1],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117,
#   1,
#   233],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117,
#   1,
#   233,
#   234],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117,
#   1,
#   233,
#   234,
#   74],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117,
#   1,
#   233,
#   234,
#   74,
#   118],
#  [72,
#   43,
#   6,
#   224,
#   42,
#   225,
#   226,
#   227,
#   12,
#   9,
#   113,
#   112,
#   228,
#   32,
#   110,
#   73,
#   111,
#   8,
#   114,
#   229,
#   10,
#   115,
#   116,
#   21,
#   230,
#   11,
#   1,
#   231,
#   232,
#   25,
#   117,
#   1,
#   233,
#   234,
#   74,
#   118,
#   15],
#  [68, 119],
#  [68, 119, 235],
#  [68, 119, 235, 12],
#  [68, 119, 235, 12, 1],
#  [68, 119, 235, 12, 1, 236],
#  [68, 119, 235, 12, 1, 236, 237],
#  [68, 119, 235, 12, 1, 236, 237, 5],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239, 240],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239, 240, 30],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239, 240, 30, 1],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239, 240, 30, 1, 241],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239, 240, 30, 1, 241, 242],
#  [68, 119, 235, 12, 1, 236, 237, 5, 238, 4, 239, 240, 30, 1, 241, 242, 243],
#  [68,
#   119,
#   235,
#   12,
#   1,
#   236,
#   237,
#   5,
#   238,
#   4,
#   239,
#   240,
#   30,
#   1,
#   241,
#   242,
#   243,
#   13],
#  [68,
#   119,
#   235,
#   12,
#   1,
#   236,
#   237,
#   5,
#   238,
#   4,
#   239,
#   240,
#   30,
#   1,
#   241,
#   242,
#   243,
#   13,
#   244],
#  [245, 246],
#  [245, 246, 53],
#  [245, 246, 53, 1],
#  [245, 246, 53, 1, 247],
#  [245, 246, 53, 1, 247, 2],
#  [245, 246, 53, 1, 247, 2, 7],
#  [245, 246, 53, 1, 247, 2, 7, 248],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22, 250],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22, 250, 251],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22, 250, 251, 75],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22, 250, 251, 75, 8],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22, 250, 251, 75, 8, 252],
#  [245, 246, 53, 1, 247, 2, 7, 248, 120, 249, 24, 22, 250, 251, 75, 8, 252, 22],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21,
#   258],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21,
#   258,
#   5],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21,
#   258,
#   5,
#   259],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21,
#   258,
#   5,
#   259,
#   75],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21,
#   258,
#   5,
#   259,
#   75,
#   260],
#  [245,
#   246,
#   53,
#   1,
#   247,
#   2,
#   7,
#   248,
#   120,
#   249,
#   24,
#   22,
#   250,
#   251,
#   75,
#   8,
#   252,
#   22,
#   253,
#   5,
#   35,
#   254,
#   54,
#   255,
#   75,
#   256,
#   257,
#   21,
#   258,
#   5,
#   259,
#   75,
#   260,
#   261],
#  [262, 12],
#  [262, 12, 9],
#  [262, 12, 9, 113],
#  [262, 12, 9, 113, 2],
#  [262, 12, 9, 113, 2, 263],
#  [262, 12, 9, 113, 2, 263, 264],
#  [262, 12, 9, 113, 2, 263, 264, 7],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68, 121],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68, 121, 268],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68, 121, 268, 76],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68, 121, 268, 76, 4],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68, 121, 268, 76, 4, 55],
#  [262, 12, 9, 113, 2, 263, 264, 7, 265, 266, 267, 68, 121, 268, 76, 4, 55, 22],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273,
#   56],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273,
#   56,
#   81],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273,
#   56,
#   81,
#   274],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273,
#   56,
#   81,
#   274,
#   71],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273,
#   56,
#   81,
#   274,
#   71,
#   13],
#  [262,
#   12,
#   9,
#   113,
#   2,
#   263,
#   264,
#   7,
#   265,
#   266,
#   267,
#   68,
#   121,
#   268,
#   76,
#   4,
#   55,
#   22,
#   77,
#   16,
#   19,
#   72,
#   18,
#   269,
#   122,
#   78,
#   270,
#   5,
#   271,
#   4,
#   79,
#   51,
#   42,
#   37,
#   272,
#   77,
#   11,
#   116,
#   123,
#   5,
#   4,
#   31,
#   14,
#   2,
#   80,
#   8,
#   273,
#   56,
#   81,
#   274,
#   71,
#   13,
#   20],
#  [7, 57],
#  [7, 57, 27],
#  [7, 57, 27, 3],
#  [7, 57, 27, 3, 1],
#  [7, 57, 27, 3, 1, 275],
#  [7, 57, 27, 3, 1, 275, 2],
#  [7, 57, 27, 3, 1, 275, 2, 276],
#  [7, 57, 27, 3, 1, 275, 2, 276, 50],
#  [7, 57, 27, 3, 1, 275, 2, 276, 50, 14],
#  [7, 57, 27, 3, 1, 275, 2, 276, 50, 14, 57],
#  [7, 57, 27, 3, 1, 275, 2, 276, 50, 14, 57, 277],
#  [7, 57, 27, 3, 1, 275, 2, 276, 50, 14, 57, 277, 8],
#  [7, 57, 27, 3, 1, 275, 2, 276, 50, 14, 57, 277, 8, 106],
#  [72, 278],
#  [72, 278, 1],
#  [72, 278, 1, 279],
#  [72, 278, 1, 279, 12],
#  [72, 278, 1, 279, 12, 280],
#  [72, 278, 1, 279, 12, 280, 3],
#  [72, 278, 1, 279, 12, 280, 3, 44],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282, 125],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282, 125, 283],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282, 125, 283, 9],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282, 125, 283, 9, 126],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282, 125, 283, 9, 126, 12],
#  [72, 278, 1, 279, 12, 280, 3, 44, 124, 18, 281, 282, 125, 283, 9, 126, 12, 1],
#  [72,
#   278,
#   1,
#   279,
#   12,
#   280,
#   3,
#   44,
#   124,
#   18,
#   281,
#   282,
#   125,
#   283,
#   9,
#   126,
#   12,
#   1,
#   34],
#  [72,
#   278,
#   1,
#   279,
#   12,
#   280,
#   3,
#   44,
#   124,
#   18,
#   281,
#   282,
#   125,
#   283,
#   9,
#   126,
#   12,
#   1,
#   34,
#   284],
#  [34, 1],
#  [34, 1, 27],
#  [34, 1, 27, 3],
#  [34, 1, 27, 3, 285],
#  [34, 1, 27, 3, 285, 47],
#  [34, 1, 27, 3, 285, 47, 1],
#  [34, 1, 27, 3, 285, 47, 1, 286],
#  [34, 1, 27, 3, 285, 47, 1, 286, 287],
#  [34, 1, 27, 3, 285, 47, 1, 286, 287, 7],
#  [34, 1, 27, 3, 285, 47, 1, 286, 287, 7, 288],
#  [34, 1, 27, 3, 285, 47, 1, 286, 287, 7, 288, 27],
#  [34, 1, 27, 3, 285, 47, 1, 286, 287, 7, 288, 27, 2],
#  [34, 1, 27, 3, 285, 47, 1, 286, 287, 7, 288, 27, 2, 127],
#  [9, 289],
#  [9, 289, 290],
#  [9, 289, 290, 1],
#  [9, 289, 290, 1, 291],
#  [9, 289, 290, 1, 291, 1],
#  [9, 289, 290, 1, 291, 1, 292],
#  [9, 289, 290, 1, 291, 1, 292, 2],
#  [9, 289, 290, 1, 291, 1, 292, 2, 293],
#  [9, 289, 290, 1, 291, 1, 292, 2, 293, 294],
#  [9, 289, 290, 1, 291, 1, 292, 2, 293, 294, 5],
#  [9, 289, 290, 1, 291, 1, 292, 2, 293, 294, 5, 82],
#  [9, 289, 290, 1, 291, 1, 292, 2, 293, 294, 5, 82, 41],
#  [18, 295],
#  [18, 295, 7],
#  [18, 295, 7, 296],
#  [18, 295, 7, 296, 297],
#  [18, 295, 7, 296, 297, 298],
#  [18, 295, 7, 296, 297, 298, 17],
#  [18, 295, 7, 296, 297, 298, 17, 3],
#  [18, 295, 7, 296, 297, 298, 17, 3, 48],
#  [18, 295, 7, 296, 297, 298, 17, 3, 48, 31],
#  [18, 295, 7, 296, 297, 298, 17, 3, 48, 31, 11],
#  [18, 295, 7, 296, 297, 298, 17, 3, 48, 31, 11, 128],
#  [1, 27],
#  [1, 27, 3],
#  [1, 27, 3, 32],
#  [1, 27, 3, 32, 129],
#  [1, 27, 3, 32, 129, 8],
#  [1, 27, 3, 32, 129, 8, 1],
#  [1, 27, 3, 32, 129, 8, 1, 57],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3, 130],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3, 130, 19],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3, 130, 19, 299],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3, 130, 19, 299, 131],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3, 130, 19, 299, 131, 1],
#  [1, 27, 3, 32, 129, 8, 1, 57, 39, 5, 9, 3, 130, 19, 299, 131, 1, 300],
#  [128, 30],
#  [128, 30, 301],
#  [128, 30, 301, 16],
#  [128, 30, 301, 16, 1],
#  [128, 30, 301, 16, 1, 39],
#  [128, 30, 301, 16, 1, 39, 302],
#  [128, 30, 301, 16, 1, 39, 302, 114],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115, 3],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115, 3, 305],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115, 3, 305, 11],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115, 3, 305, 11, 1],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115, 3, 305, 11, 1, 127],
#  [128, 30, 301, 16, 1, 39, 302, 114, 303, 304, 115, 3, 305, 11, 1, 127, 8],
#  [128,
#   30,
#   301,
#   16,
#   1,
#   39,
#   302,
#   114,
#   303,
#   304,
#   115,
#   3,
#   305,
#   11,
#   1,
#   127,
#   8,
#   306],
#  [128,
#   30,
#   301,
#   16,
#   1,
#   39,
#   302,
#   114,
#   303,
#   304,
#   115,
#   3,
#   305,
#   11,
#   1,
#   127,
#   8,
#   306,
#   307],
#  [79, 1],
#  [79, 1, 27],
#  [79, 1, 27, 3],
#  [79, 1, 27, 3, 132],
#  [79, 1, 27, 3, 132, 308],
#  [79, 1, 27, 3, 132, 308, 8],
#  [79, 1, 27, 3, 132, 308, 8, 1],
#  [79, 1, 27, 3, 132, 308, 8, 1, 309],
#  [79, 1, 27, 3, 132, 308, 8, 1, 309, 5],
#  [79, 1, 27, 3, 132, 308, 8, 1, 309, 5, 18],
#  [79, 1, 27, 3, 132, 308, 8, 1, 309, 5, 18, 3],
#  [79, 1, 27, 3, 132, 308, 8, 1, 309, 5, 18, 3, 310],
#  [79, 1, 27, 3, 132, 308, 8, 1, 309, 5, 18, 3, 310, 311],
#  [47, 7],
#  [47, 7, 27],
#  [47, 7, 27, 3],
#  [47, 7, 27, 3, 129],
#  [47, 7, 27, 3, 129, 18],
#  [47, 7, 27, 3, 129, 18, 3],
#  [47, 7, 27, 3, 129, 18, 3, 312],
#  [47, 7, 27, 3, 129, 18, 3, 312, 133],
#  [47, 7, 27, 3, 129, 18, 3, 312, 133, 5],
#  [47, 7, 27, 3, 129, 18, 3, 312, 133, 5, 313],
#  [47, 7, 27, 3, 129, 18, 3, 312, 133, 5, 313, 30],
#  [47, 7, 27, 3, 129, 18, 3, 312, 133, 5, 313, 30, 314],
#  [47, 7, 27, 3, 129, 18, 3, 312, 133, 5, 313, 30, 314, 15],
#  [7, 315],
#  [7, 315, 316],
#  [7, 315, 316, 317],
#  [7, 315, 316, 317, 58],
#  [7, 315, 316, 317, 58, 134],
#  [7, 315, 316, 317, 58, 134, 103],
#  [7, 315, 316, 317, 58, 134, 103, 318],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30, 320],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30, 320, 321],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30, 320, 321, 135],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30, 320, 321, 135, 322],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30, 320, 321, 135, 322, 24],
#  [7, 315, 316, 317, 58, 134, 103, 318, 319, 30, 320, 321, 135, 322, 24, 10],
#  [7,
#   315,
#   316,
#   317,
#   58,
#   134,
#   103,
#   318,
#   319,
#   30,
#   320,
#   321,
#   135,
#   322,
#   24,
#   10,
#   83],
#  [7,
#   315,
#   316,
#   317,
#   58,
#   134,
#   103,
#   318,
#   319,
#   30,
#   320,
#   321,
#   135,
#   322,
#   24,
#   10,
#   83,
#   70],
#  [7,
#   315,
#   316,
#   317,
#   58,
#   134,
#   103,
#   318,
#   319,
#   30,
#   320,
#   321,
#   135,
#   322,
#   24,
#   10,
#   83,
#   70,
#   11],
#  [7,
#   315,
#   316,
#   317,
#   58,
#   134,
#   103,
#   318,
#   319,
#   30,
#   320,
#   321,
#   135,
#   322,
#   24,
#   10,
#   83,
#   70,
#   11,
#   323],
#  [7,
#   315,
#   316,
#   317,
#   58,
#   134,
#   103,
#   318,
#   319,
#   30,
#   320,
#   321,
#   135,
#   322,
#   24,
#   10,
#   83,
#   70,
#   11,
#   323,
#   324],
#  [18, 136],
#  [18, 136, 58],
#  [18, 136, 58, 325],
#  [18, 136, 58, 325, 59],
#  [18, 136, 58, 325, 59, 29],
#  [18, 136, 58, 325, 59, 29, 2],
#  [18, 136, 58, 325, 59, 29, 2, 57],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137, 326],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137, 326, 5],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137, 326, 5, 69],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137, 326, 5, 69, 1],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137, 326, 5, 69, 1, 327],
#  [18, 136, 58, 325, 59, 29, 2, 57, 27, 10, 1, 15, 137, 326, 5, 69, 1, 327, 2],
#  [18,
#   136,
#   58,
#   325,
#   59,
#   29,
#   2,
#   57,
#   27,
#   10,
#   1,
#   15,
#   137,
#   326,
#   5,
#   69,
#   1,
#   327,
#   2,
#   328],
#  [18,
#   136,
#   58,
#   325,
#   59,
#   29,
#   2,
#   57,
#   27,
#   10,
#   1,
#   15,
#   137,
#   326,
#   5,
#   69,
#   1,
#   327,
#   2,
#   328,
#   74],
#  [18,
#   136,
#   58,
#   325,
#   59,
#   29,
#   2,
#   57,
#   27,
#   10,
#   1,
#   15,
#   137,
#   326,
#   5,
#   69,
#   1,
#   327,
#   2,
#   328,
#   74,
#   80],
#  [9, 10],
#  [9, 10, 3],
#  [9, 10, 3, 44],
#  [9, 10, 3, 44, 49],
#  [9, 10, 3, 44, 49, 84],
#  [9, 10, 3, 44, 49, 84, 13],
#  [9, 10, 3, 44, 49, 84, 13, 20],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49, 107],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49, 107, 19],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49, 107, 19, 28],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49, 107, 19, 28, 12],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49, 107, 19, 28, 12, 7],
#  [9, 10, 3, 44, 49, 84, 13, 20, 329, 21, 7, 29, 2, 49, 107, 19, 28, 12, 7, 37],
#  [9,
#   10,
#   3,
#   44,
#   49,
#   84,
#   13,
#   20,
#   329,
#   21,
#   7,
#   29,
#   2,
#   49,
#   107,
#   19,
#   28,
#   12,
#   7,
#   37,
#   330],
#  [28, 331],
#  [28, 331, 332],
#  [28, 331, 332, 45],
#  [28, 331, 332, 45, 333],
#  [28, 331, 332, 45, 333, 2],
#  [28, 331, 332, 45, 333, 2, 334],
#  [28, 331, 332, 45, 333, 2, 334, 39],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138, 6],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138, 6, 336],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138, 6, 336, 337],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138, 6, 336, 337, 24],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138, 6, 336, 337, 24, 85],
#  [28, 331, 332, 45, 333, 2, 334, 39, 335, 1, 138, 6, 336, 337, 24, 85, 338],
#  [28,
#   331,
#   332,
#   45,
#   333,
#   2,
#   334,
#   39,
#   335,
#   1,
#   138,
#   6,
#   336,
#   337,
#   24,
#   85,
#   338,
#   74],
#  [28,
#   331,
#   332,
#   45,
#   333,
#   2,
#   334,
#   39,
#   335,
#   1,
#   138,
#   6,
#   336,
#   337,
#   24,
#   85,
#   338,
#   74,
#   19],
#  [339, 43],
#  [339, 43, 6],
#  [339, 43, 6, 340],
#  [339, 43, 6, 340, 341],
#  [339, 43, 6, 340, 341, 342],
#  [339, 43, 6, 340, 341, 342, 343],
#  [339, 43, 6, 340, 341, 342, 343, 15],
#  [339, 43, 6, 340, 341, 342, 343, 15, 5],
#  [339, 43, 6, 340, 341, 342, 343, 15, 5, 344],
#  [339, 43, 6, 340, 341, 342, 343, 15, 5, 344, 345],
#  [339, 43, 6, 340, 341, 342, 343, 15, 5, 344, 345, 69],
#  [43, 6],
#  [43, 6, 45],
#  [43, 6, 45, 37],
#  [43, 6, 45, 37, 346],
#  [43, 6, 45, 37, 346, 11],
#  [43, 6, 45, 37, 346, 11, 1],
#  [43, 6, 45, 37, 346, 11, 1, 15],
#  [1, 27],
#  [1, 27, 13],
#  [1, 27, 13, 20],
#  [1, 27, 13, 20, 347],
#  [1, 27, 13, 20, 347, 21],
#  [1, 27, 13, 20, 347, 21, 60],
#  [1, 27, 13, 20, 347, 21, 60, 61],
#  [1, 27, 13, 20, 347, 21, 60, 61, 25],
#  [1, 27, 13, 20, 347, 21, 60, 61, 25, 348],
#  [28, 26],
#  [28, 26, 67],
#  [28, 26, 67, 86],
#  [28, 26, 67, 86, 349],
#  [28, 26, 67, 86, 349, 38],
#  [28, 26, 67, 86, 349, 38, 87],
#  [28, 26, 67, 86, 349, 38, 87, 350],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14, 27],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14, 27, 5],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14, 27, 5, 139],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14, 27, 5, 139, 53],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14, 27, 5, 139, 53, 46],
#  [28, 26, 67, 86, 349, 38, 87, 350, 14, 27, 5, 139, 53, 46, 38],
#  [1, 34],
#  [1, 34, 351],
#  [1, 34, 351, 6],
#  [1, 34, 351, 6, 140],
#  [1, 34, 351, 6, 140, 41],
#  [1, 34, 351, 6, 140, 41, 17],
#  [1, 34, 351, 6, 140, 41, 17, 3],
#  [1, 34, 351, 6, 140, 41, 17, 3, 352],
#  [1, 34, 351, 6, 140, 41, 17, 3, 352, 53],
#  [1, 34, 351, 6, 140, 41, 17, 3, 352, 53, 1],
#  [1, 34, 351, 6, 140, 41, 17, 3, 352, 53, 1, 353],
#  [11, 141],
#  [11, 141, 10],
#  [11, 141, 10, 28],
#  [11, 141, 10, 28, 26],
#  [11, 141, 10, 28, 26, 86],
#  [11, 141, 10, 28, 26, 86, 46],
#  [11, 141, 10, 28, 26, 86, 46, 142],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2, 15],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2, 15, 17],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2, 15, 17, 6],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2, 15, 17, 6, 14],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2, 15, 17, 6, 14, 354],
#  [11, 141, 10, 28, 26, 86, 46, 142, 143, 2, 15, 17, 6, 14, 354, 144],
#  [1, 355],
#  [1, 355, 2],
#  [1, 355, 2, 36],
#  [1, 355, 2, 36, 15],
#  [1, 355, 2, 36, 15, 3],
#  [1, 355, 2, 36, 15, 3, 356],
#  [1, 355, 2, 36, 15, 3, 356, 21],
#  [1, 355, 2, 36, 15, 3, 356, 21, 7],
#  [1, 355, 2, 36, 15, 3, 356, 21, 7, 26],
#  [1, 355, 2, 36, 15, 3, 356, 21, 7, 26, 357],
#  [76, 4],
#  [76, 4, 358],
#  [76, 4, 358, 8],
#  [76, 4, 358, 8, 137],
#  [76, 4, 358, 8, 137, 1],
#  [76, 4, 358, 8, 137, 1, 10],
#  [76, 4, 358, 8, 137, 1, 10, 102],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359, 8],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359, 8, 360],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359, 8, 360, 1],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359, 8, 360, 1, 143],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359, 8, 360, 1, 143, 361],
#  [76, 4, 358, 8, 137, 1, 10, 102, 145, 18, 3, 359, 8, 360, 1, 143, 361, 21],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38,
#   6],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38,
#   6,
#   147],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38,
#   6,
#   147,
#   38],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38,
#   6,
#   147,
#   38,
#   2],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38,
#   6,
#   147,
#   38,
#   2,
#   36],
#  [76,
#   4,
#   358,
#   8,
#   137,
#   1,
#   10,
#   102,
#   145,
#   18,
#   3,
#   359,
#   8,
#   360,
#   1,
#   143,
#   361,
#   21,
#   362,
#   35,
#   1,
#   146,
#   38,
#   6,
#   147,
#   38,
#   2,
#   36,
#   148],
#  [58, 105],
#  [58, 105, 2],
#  [58, 105, 2, 363],
#  [58, 105, 2, 363, 121],
#  [58, 105, 2, 363, 121, 20],
#  [58, 105, 2, 363, 121, 20, 1],
#  [58, 105, 2, 363, 121, 20, 1, 364],
#  [58, 105, 2, 363, 121, 20, 1, 364, 365],
#  [58, 105, 2, 363, 121, 20, 1, 364, 365, 366],
#  [58, 105, 2, 363, 121, 20, 1, 364, 365, 366, 367],
#  [58, 105, 2, 363, 121, 20, 1, 364, 365, 366, 367, 5],
#  [58, 105, 2, 363, 121, 20, 1, 364, 365, 366, 367, 5, 368],
#  [58, 105, 2, 363, 121, 20, 1, 364, 365, 366, 367, 5, 368, 369],
#  [370, 2],
#  [370, 2, 62],
#  [370, 2, 62, 140],
#  [370, 2, 62, 140, 41],
#  [149, 40],
#  [149, 40, 148],
#  [149, 40, 148, 371],
#  [149, 40, 148, 371, 1],
#  [149, 40, 148, 371, 1, 150],
#  [149, 40, 148, 371, 1, 150, 372],
#  [6, 61],
#  [6, 61, 15],
#  [6, 61, 15, 117],
#  [6, 61, 15, 117, 54],
#  [6, 61, 15, 117, 54, 88],
#  [6, 61, 15, 117, 54, 88, 151],
#  [6, 61, 15, 117, 54, 88, 151, 60],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4, 374],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4, 374, 133],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4, 374, 133, 24],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4, 374, 133, 24, 85],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4, 374, 133, 24, 85, 37],
#  [6, 61, 15, 117, 54, 88, 151, 60, 373, 4, 374, 133, 24, 85, 37, 375],
#  [34, 4],
#  [34, 4, 376],
#  [34, 4, 376, 377],
#  [34, 4, 376, 377, 40],
#  [34, 4, 376, 377, 40, 1],
#  [34, 4, 376, 377, 40, 1, 62],
#  [34, 4, 376, 377, 40, 1, 62, 15],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10, 83],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10, 83, 39],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10, 83, 39, 23],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10, 83, 39, 23, 25],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10, 83, 39, 23, 25, 152],
#  [34, 4, 376, 377, 40, 1, 62, 15, 21, 378, 73, 7, 10, 83, 39, 23, 25, 152, 11],
#  [34,
#   4,
#   376,
#   377,
#   40,
#   1,
#   62,
#   15,
#   21,
#   378,
#   73,
#   7,
#   10,
#   83,
#   39,
#   23,
#   25,
#   152,
#   11,
#   379],
#  [4, 380],
#  [4, 380, 8],
#  [4, 380, 8, 381],
#  [4, 380, 8, 381, 1],
#  [4, 380, 8, 381, 1, 382],
#  [4, 380, 8, 381, 1, 382, 24],
#  [4, 380, 8, 381, 1, 382, 24, 1],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39, 90],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39, 90, 23],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39, 90, 23, 5],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39, 90, 23, 5, 66],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39, 90, 23, 5, 66, 91],
#  [4, 380, 8, 381, 1, 382, 24, 1, 14, 2, 7, 10, 89, 39, 90, 23, 5, 66, 91, 14],
#  [4,
#   380,
#   8,
#   381,
#   1,
#   382,
#   24,
#   1,
#   14,
#   2,
#   7,
#   10,
#   89,
#   39,
#   90,
#   23,
#   5,
#   66,
#   91,
#   14,
#   383],
#  [4,
#   380,
#   8,
#   381,
#   1,
#   382,
#   24,
#   1,
#   14,
#   2,
#   7,
#   10,
#   89,
#   39,
#   90,
#   23,
#   5,
#   66,
#   91,
#   14,
#   383,
#   145],
#  [9, 92],
#  [9, 92, 14],
#  [9, 92, 14, 384],
#  [9, 92, 14, 384, 44],
#  [9, 92, 14, 384, 44, 40],
#  [9, 92, 14, 384, 44, 40, 15],
#  [9, 92, 14, 384, 44, 40, 15, 6],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150, 385],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150, 385, 30],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150, 385, 30, 386],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150, 385, 30, 386, 80],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150, 385, 30, 386, 80, 37],
#  [9, 92, 14, 384, 44, 40, 15, 6, 2, 1, 150, 385, 30, 386, 80, 37, 153],
#  [84, 81],
#  [84, 81, 387],
#  [84, 81, 387, 4],
#  [84, 81, 387, 4, 388],
#  [84, 81, 387, 4, 388, 22],
#  [84, 81, 387, 4, 388, 22, 389],
#  [84, 81, 387, 4, 388, 22, 389, 154],
#  [43, 6],
#  [43, 6, 42],
#  [43, 6, 42, 390],
#  [43, 6, 42, 390, 5],
#  [43, 6, 42, 390, 5, 4],
#  [43, 6, 42, 390, 5, 4, 391],
#  [43, 6, 42, 390, 5, 4, 391, 11],
#  [43, 6, 42, 390, 5, 4, 391, 11, 1],
#  [43, 6, 42, 390, 5, 4, 391, 11, 1, 392],
#  [43, 6, 42, 390, 5, 4, 391, 11, 1, 392, 155],
#  [393, 22],
#  [393, 22, 394],
#  [393, 22, 394, 395],
#  [393, 22, 394, 395, 1],
#  [393, 22, 394, 395, 1, 396],
#  [393, 22, 394, 395, 1, 396, 156],
#  [393, 22, 394, 395, 1, 396, 156, 397],
#  [393, 22, 394, 395, 1, 396, 156, 397, 3],
#  [393, 22, 394, 395, 1, 396, 156, 397, 3, 7],
#  [393, 22, 394, 395, 1, 396, 156, 397, 3, 7, 398],
#  [393, 22, 394, 395, 1, 396, 156, 397, 3, 7, 398, 399],
#  [393, 22, 394, 395, 1, 396, 156, 397, 3, 7, 398, 399, 14],
#  [400, 7],
#  [400, 7, 26],
#  [400, 7, 26, 8],
#  [400, 7, 26, 8, 20],
#  [400, 7, 26, 8, 20, 60],
#  [400, 7, 26, 8, 20, 60, 5],
#  [400, 7, 26, 8, 20, 60, 5, 18],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52, 402],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52, 402, 151],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52, 402, 151, 1],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52, 402, 151, 1, 82],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52, 402, 151, 1, 82, 52],
#  [400, 7, 26, 8, 20, 60, 5, 18, 3, 401, 61, 3, 52, 402, 151, 1, 82, 52, 403],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9,
#   155],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9,
#   155,
#   157],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9,
#   155,
#   157,
#   404],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9,
#   155,
#   157,
#   404,
#   12],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9,
#   155,
#   157,
#   404,
#   12,
#   9],
#  [400,
#   7,
#   26,
#   8,
#   20,
#   60,
#   5,
#   18,
#   3,
#   401,
#   61,
#   3,
#   52,
#   402,
#   151,
#   1,
#   82,
#   52,
#   403,
#   35,
#   9,
#   155,
#   157,
#   404,
#   12,
#   9,
#   405],
#  [28, 26],
#  [28, 26, 2],
#  [28, 26, 2, 1],
#  [28, 26, 2, 1, 10],
#  [28, 26, 2, 1, 10, 3],
#  [28, 26, 2, 1, 10, 3, 108],
#  [28, 26, 2, 1, 10, 3, 108, 21],
#  [28, 26, 2, 1, 10, 3, 108, 21, 7],
#  [28, 26, 2, 1, 10, 3, 108, 21, 7, 406],
#  [28, 26, 2, 1, 10, 3, 108, 21, 7, 406, 407],
#  [141, 408],
#  [141, 408, 14],
#  [141, 408, 14, 2],
#  [141, 408, 14, 2, 36],
#  [141, 408, 14, 2, 36, 3],
#  [141, 408, 14, 2, 36, 3, 32],
#  [141, 408, 14, 2, 36, 3, 32, 158],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30, 409],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30, 409, 41],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30, 409, 41, 50],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30, 409, 41, 50, 46],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30, 409, 41, 50, 46, 62],
#  [141, 408, 14, 2, 36, 3, 32, 158, 30, 409, 41, 50, 46, 62, 15],
#  [1, 159],
#  [1, 159, 3],
#  [1, 159, 3, 410],
#  [1, 159, 3, 410, 10],
#  [1, 159, 3, 410, 10, 63],
#  [1, 159, 3, 410, 10, 63, 5],
#  [1, 159, 3, 410, 10, 63, 5, 3],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1, 63],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1, 63, 12],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1, 63, 12, 412],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1, 63, 12, 412, 83],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1, 63, 12, 412, 83, 161],
#  [1, 159, 3, 410, 10, 63, 5, 3, 411, 160, 16, 1, 63, 12, 412, 83, 161, 70],
#  [1,
#   159,
#   3,
#   410,
#   10,
#   63,
#   5,
#   3,
#   411,
#   160,
#   16,
#   1,
#   63,
#   12,
#   412,
#   83,
#   161,
#   70,
#   162],
#  [9, 23],
#  [9, 23, 3],
#  [9, 23, 3, 56],
#  [9, 23, 3, 56, 14],
#  [9, 23, 3, 56, 14, 2],
#  [9, 23, 3, 56, 14, 2, 42],
#  [9, 23, 3, 56, 14, 2, 42, 12],
#  [9, 23, 3, 56, 14, 2, 42, 12, 1],
#  [9, 23, 3, 56, 14, 2, 42, 12, 1, 10],
#  [9, 23, 3, 56, 14, 2, 42, 12, 1, 10, 161],
#  [9, 23, 3, 56, 14, 2, 42, 12, 1, 10, 161, 39],
#  [9, 23, 3, 56, 14, 2, 42, 12, 1, 10, 161, 39, 163],
#  [9, 23, 3, 56, 14, 2, 42, 12, 1, 10, 161, 39, 163, 413],
#  [71, 40],
#  [71, 40, 414],
#  [71, 40, 414, 93],
#  [71, 40, 414, 93, 17],
#  [71, 40, 414, 93, 17, 6],
#  [71, 40, 414, 93, 17, 6, 48],
#  [71, 40, 414, 93, 17, 6, 48, 31],
#  [71, 40, 414, 93, 17, 6, 48, 31, 11],
#  [71, 40, 414, 93, 17, 6, 48, 31, 11, 415],
#  [71, 40, 414, 93, 17, 6, 48, 31, 11, 415, 123],
#  [76, 118],
#  [76, 118, 93],
#  [76, 118, 93, 6],
#  [76, 118, 93, 6, 416],
#  [76, 118, 93, 6, 416, 12],
#  [76, 118, 93, 6, 416, 12, 417],
#  [76, 118, 93, 6, 416, 12, 417, 94],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15, 12],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15, 12, 1],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15, 12, 1, 419],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15, 12, 1, 419, 10],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15, 12, 1, 419, 10, 6],
#  [76, 118, 93, 6, 416, 12, 417, 94, 418, 1, 15, 12, 1, 419, 10, 6, 420],
#  [1, 421],
#  [1, 421, 125],
#  [1, 421, 125, 4],
#  [1, 421, 125, 4, 422],
#  [1, 421, 125, 4, 422, 36],
#  [1, 421, 125, 4, 422, 36, 5],
#  [1, 421, 125, 4, 422, 36, 5, 44],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162, 3],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162, 3, 17],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162, 3, 17, 19],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162, 3, 17, 19, 12],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162, 3, 17, 19, 12, 424],
#  [1, 421, 125, 4, 422, 36, 5, 44, 56, 64, 423, 162, 3, 17, 19, 12, 424, 51],
#  [1,
#   421,
#   125,
#   4,
#   422,
#   36,
#   5,
#   44,
#   56,
#   64,
#   423,
#   162,
#   3,
#   17,
#   19,
#   12,
#   424,
#   51,
#   425],
#  [1,
#   421,
#   125,
#   4,
#   422,
#   36,
#   5,
#   44,
#   56,
#   64,
#   423,
#   162,
#   3,
#   17,
#   19,
#   12,
#   424,
#   51,
#   425,
#   426],
#  [1, 95],
#  [1, 95, 2],
#  [1, 95, 2, 7],
#  [1, 95, 2, 7, 10],
#  [1, 95, 2, 7, 10, 3],
#  [1, 95, 2, 7, 10, 3, 427],
#  [1, 95, 2, 7, 10, 3, 427, 5],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23, 429],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23, 429, 430],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23, 429, 430, 16],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23, 429, 430, 16, 46],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23, 429, 430, 16, 46, 431],
#  [1, 95, 2, 7, 10, 3, 427, 5, 1, 428, 2, 1, 23, 429, 430, 16, 46, 431, 95],
#  [79, 8],
#  [79, 8, 432],
#  [79, 8, 432, 9],
#  [79, 8, 432, 9, 126],
#  [79, 8, 432, 9, 126, 87],
#  [79, 8, 432, 9, 126, 87, 139],
#  [79, 8, 432, 9, 126, 87, 139, 53],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95, 28],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95, 28, 26],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95, 28, 26, 434],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95, 28, 26, 434, 46],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95, 28, 26, 434, 46, 142],
#  [79, 8, 432, 9, 126, 87, 139, 53, 1, 433, 163, 95, 28, 26, 434, 46, 142, 435],
#  [79,
#   8,
#   432,
#   9,
#   126,
#   87,
#   139,
#   53,
#   1,
#   433,
#   163,
#   95,
#   28,
#   26,
#   434,
#   46,
#   142,
#   435,
#   10],
#  [4, 436],
#  [4, 436, 1],
#  [4, 436, 1, 93],
#  [4, 436, 1, 93, 12],
#  [4, 436, 1, 93, 12, 45],
#  [4, 436, 1, 93, 12, 45, 124],
#  [4, 436, 1, 93, 12, 45, 124, 138],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34, 28],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34, 28, 62],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34, 28, 62, 26],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34, 28, 62, 26, 437],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34, 28, 62, 26, 437, 7],
#  [4, 436, 1, 93, 12, 45, 124, 138, 34, 28, 62, 26, 437, 7, 164],
#  [1, 438],
#  [1, 438, 6],
#  [1, 438, 6, 32],
#  [1, 438, 6, 32, 147],
#  [1, 438, 6, 32, 147, 5],
#  [1, 438, 6, 32, 147, 5, 132],
#  [1, 438, 6, 32, 147, 5, 132, 1],
#  [1, 438, 6, 32, 147, 5, 132, 1, 94],
#  [1, 438, 6, 32, 147, 5, 132, 1, 94, 2],
#  [1, 438, 6, 32, 147, 5, 132, 1, 94, 2, 22],
#  [1, 438, 6, 32, 147, 5, 132, 1, 94, 2, 22, 26],
#  [1, 438, 6, 32, 147, 5, 132, 1, 94, 2, 22, 26, 3],
#  [1, 438, 6, 32, 147, 5, 132, 1, 94, 2, 22, 26, 3, 158],
#  [1, 96],
#  [1, 96, 439],
#  [1, 96, 439, 47],
#  [1, 96, 439, 47, 73],
#  [1, 96, 439, 47, 73, 90],
#  [1, 96, 439, 47, 73, 90, 3],
#  [1, 96, 439, 47, 73, 90, 3, 17],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1, 440],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1, 440, 84],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1, 440, 84, 165],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1, 440, 84, 165, 4],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1, 440, 84, 165, 4, 441],
#  [1, 96, 439, 47, 73, 90, 3, 17, 4, 149, 44, 122, 1, 440, 84, 165, 4, 441, 89],
#  [1,
#   96,
#   439,
#   47,
#   73,
#   90,
#   3,
#   17,
#   4,
#   149,
#   44,
#   122,
#   1,
#   440,
#   84,
#   165,
#   4,
#   441,
#   89,
#   153],
#  [1,
#   96,
#   439,
#   47,
#   73,
#   90,
#   3,
#   17,
#   4,
#   149,
#   44,
#   122,
#   1,
#   440,
#   84,
#   165,
#   4,
#   441,
#   89,
#   153,
#   8],
#  [1,
#   96,
#   439,
#   47,
#   73,
#   90,
#   3,
#   17,
#   4,
#   149,
#   44,
#   122,
#   1,
#   440,
#   84,
#   165,
#   4,
#   441,
#   89,
#   153,
#   8,
#   28],
#  [1,
#   96,
#   439,
#   47,
#   73,
#   90,
#   3,
#   17,
#   4,
#   149,
#   44,
#   122,
#   1,
#   440,
#   84,
#   165,
#   4,
#   441,
#   89,
#   153,
#   8,
#   28,
#   164],
#  [36, 6],
#  [36, 6, 67],
#  [36, 6, 67, 442],
#  [9, 52],
#  [9, 52, 4],
#  [9, 52, 4, 13],
#  [9, 52, 4, 13, 443],
#  [9, 52, 4, 13, 443, 54],
#  [9, 52, 4, 13, 443, 54, 89],
#  [9, 52, 4, 13, 443, 54, 89, 8],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2, 1],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2, 1, 59],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2, 1, 59, 4],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2, 1, 59, 4, 31],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2, 1, 59, 4, 31, 11],
#  [9, 52, 4, 13, 443, 54, 89, 8, 1, 88, 444, 2, 1, 59, 4, 31, 11, 65],
#  [12, 1],
#  [12, 1, 445],
#  [12, 1, 445, 446],
#  [12, 1, 445, 446, 4],
#  [12, 1, 445, 446, 4, 13],
#  [12, 1, 445, 446, 4, 13, 66],
#  [12, 1, 445, 446, 4, 13, 66, 17],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6, 31],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6, 31, 33],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6, 31, 33, 167],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6, 31, 33, 167, 1],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6, 31, 33, 167, 1, 92],
#  [12, 1, 445, 446, 4, 13, 66, 17, 33, 166, 6, 31, 33, 167, 1, 92, 14],
#  [9, 447],
#  [9, 447, 4],
#  [9, 447, 4, 448],
#  [9, 447, 4, 448, 59],
#  [9, 447, 4, 448, 59, 50],
#  [9, 447, 4, 448, 59, 50, 33],
#  [9, 447, 4, 448, 59, 50, 33, 449],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15, 450],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15, 450, 451],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15, 450, 451, 6],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15, 450, 451, 6, 2],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15, 450, 451, 6, 2, 9],
#  [9, 447, 4, 448, 59, 50, 33, 449, 144, 5, 96, 1, 15, 450, 451, 6, 2, 9, 452],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25,
#   453],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25,
#   453,
#   13],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25,
#   453,
#   13,
#   454],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25,
#   453,
#   13,
#   454,
#   22],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25,
#   453,
#   13,
#   454,
#   22,
#   455],
#  [9,
#   447,
#   4,
#   448,
#   59,
#   50,
#   33,
#   449,
#   144,
#   5,
#   96,
#   1,
#   15,
#   450,
#   451,
#   6,
#   2,
#   9,
#   452,
#   25,
#   453,
#   13,
#   454,
#   22,
#   455,
#   94],
#  [1, 456],
#  [1, 456, 2],
#  [1, 456, 2, 457],
#  [1, 456, 2, 457, 17],
#  [1, 456, 2, 457, 17, 6],
#  [1, 456, 2, 457, 17, 6, 167],
#  [1, 456, 2, 457, 17, 6, 167, 458],
#  [1, 456, 2, 457, 17, 6, 167, 458, 459],
#  [1, 456, 2, 457, 17, 6, 167, 458, 459, 6],
#  ...]

# %%
max_len=max(len(x) for x in input_seq)
print(max_len)
# Out:
# 53

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_seq=pad_sequences(input_seq,maxlen=max_len,padding='pre')

# %%
print(padded_input_seq)
# Out:
# [[  0   0   0 ...   0   4  13]
#  [  0   0   0 ...   4  13 177]
#  [  0   0   0 ...  13 177   1]
#  ...
#  [  0   0   0 ...   0   9   3]
#  [  0   0   0 ...   9   3   1]
#  [  0   0   0 ...   3   1 520]]

# %%
X=padded_input_seq[:,:-1]
print(X)
# Out:
# [[  0   0   0 ...   0   0   4]
#  [  0   0   0 ...   0   4  13]
#  [  0   0   0 ...   4  13 177]
#  ...
#  [  0   0   0 ...   0   0   9]
#  [  0   0   0 ...   0   9   3]
#  [  0   0   0 ...   9   3   1]]

# %%
y=padded_input_seq[:,-1]
print(y)
# Out:
# [ 13 177   1 ...   3   1 520]

# %%
X.shape
# Out:
# (1271, 52)

# %%
y.shape
# Out:
# (1271,)

# %%
from tensorflow.keras.utils import to_categorical
y=to_categorical(y,num_classes=len(tokenizer.word_index)+1)

# %%
y.shape
# Out:
# (1271, 521)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(521, 100, input_length=max_len - 1))  # Specify input_length
model.add(LSTM(213))
model.add(Dense(521, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.0603 - loss: 6.1005
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.0642 - loss: 5.5992
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.0590 - loss: 5.5616
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0595 - loss: 5.4973
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.0593 - loss: 5.4743
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0733 - loss: 5.2476
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0813 - loss: 5.1395
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0966 - loss: 4.9571
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1235 - loss: 4.7817
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1570 - loss: 4.5606
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1724 - loss: 4.3269
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1718 - loss: 4.1026
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2050 - loss: 3.8256
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2434 - loss: 3.5641
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2704 - loss: 3.3876
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3536 - loss: 3.0648
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4082 - loss: 2.7762
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4780 - loss: 2.5495
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5800 - loss: 2.3030
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6088 - loss: 2.1094
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6536 - loss: 1.9615
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6979 - loss: 1.7701
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7299 - loss: 1.5945
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8022 - loss: 1.4493
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8286 - loss: 1.2788
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8574 - loss: 1.1562
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8834 - loss: 1.0002
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8912 - loss: 0.9403
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8970 - loss: 0.8568
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9179 - loss: 0.7838
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9330 - loss: 0.6832
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9324 - loss: 0.6575
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9421 - loss: 0.5942
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9499 - loss: 0.5444
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.5274
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9463 - loss: 0.4720
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9594 - loss: 0.4166
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9678 - loss: 0.3613
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9673 - loss: 0.3513
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9652 - loss: 0.3283
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9693 - loss: 0.3028
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9646 - loss: 0.2859
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9726 - loss: 0.2583
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9696 - loss: 0.2419
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9681 - loss: 0.2403
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9659 - loss: 0.2396
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9584 - loss: 0.2373
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9584 - loss: 0.2320
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9727 - loss: 0.1921
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9656 - loss: 0.1946
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9639 - loss: 0.1881
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9672 - loss: 0.1725
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9677 - loss: 0.1753
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9623 - loss: 0.1789
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9600 - loss: 0.1721
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9695 - loss: 0.1553
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9548 - loss: 0.1609
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9691 - loss: 0.1486
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9540 - loss: 0.1525
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9683 - loss: 0.1397
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9586 - loss: 0.1448
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9634 - loss: 0.1361
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9610 - loss: 0.1363
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9567 - loss: 0.1438
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9542 - loss: 0.1399
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9594 - loss: 0.1304
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9621 - loss: 0.1279
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9738 - loss: 0.1007
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.1045
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9587 - loss: 0.1231
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9703 - loss: 0.1131
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9699 - loss: 0.1002
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9684 - loss: 0.1089
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9615 - loss: 0.1159
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9645 - loss: 0.1103
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9608 - loss: 0.1325
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9570 - loss: 0.1161
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9686 - loss: 0.1032
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9637 - loss: 0.1043
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9592 - loss: 0.1148
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9724 - loss: 0.0890
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9681 - loss: 0.0901
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9711 - loss: 0.0902
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9625 - loss: 0.1063
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9661 - loss: 0.1039
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9664 - loss: 0.0939
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9709 - loss: 0.0846
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9631 - loss: 0.1010
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9771 - loss: 0.0819
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9671 - loss: 0.0959
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9689 - loss: 0.0830
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9665 - loss: 0.0952
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9723 - loss: 0.0882
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.0947
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9719 - loss: 0.0747
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9599 - loss: 0.1009
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9620 - loss: 0.1019
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9635 - loss: 0.0938
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9655 - loss: 0.0903
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9694 - loss: 0.0829

# %%
import numpy as np

# %%
pred_text="The messages"

for i in range(10):
#tokenize
  token_text=tokenizer.texts_to_sequences([pred_text])[0]
  #pad
  padded_token_text=pad_sequences([token_text],maxlen=max_len,padding='pre')
  #print(padded_token_text)
  #predict
  pos=np.argmax(model.predict(padded_token_text))
  for word,index in tokenizer.word_index.items():
    if index==pos:
      pred_text=pred_text + " " + word
      print(pred_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# The messages are
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The messages are then
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# The messages are then aggregated
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The messages are then aggregated and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# The messages are then aggregated and finally
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The messages are then aggregated and finally the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# The messages are then aggregated and finally the embedding
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The messages are then aggregated and finally the embedding of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# The messages are then aggregated and finally the embedding of our
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# The messages are then aggregated and finally the embedding of our node
